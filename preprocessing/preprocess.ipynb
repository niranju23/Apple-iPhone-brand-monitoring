# %%
import pandas as pd
from textblob import TextBlob
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from spellchecker import SpellChecker  # Import SpellChecker (You can remove this)
import string
import ssl
from spellchecker import SpellChecker  # Import SpellChecker from pyspellchecker
ssl._create_default_https_context = ssl._create_unverified_context

nltk.download('stopwords')

# Load the CSV file into a pandas DataFrame
csv_file_path = 'Data_collection/sample_data/output.csv'
data = pd.read_csv(csv_file_path)

# Assuming your CSV file has a column named 'review' that contains the reviews
reviews = data['review']

# Preprocess the text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    
    text = text.replace("read more",'')
    
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize the text
    words = text.split()
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    # Apply stemming using PorterStemmer
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]
    
    # Join the words back into a processed text
    processed_text = ' '.join(words)
    
    return processed_text

# Spell checking and correction function using pyspellchecker
def correct_spelling(text):
    spell = SpellChecker()
    words = text.split()
    
    corrected_words = []
    for word in words:
        corrected_word = spell.correction(word)
        if corrected_word is not None:
            corrected_words.append(corrected_word)
    
    corrected_text = ' '.join(corrected_words)
    
    return corrected_text


# Apply preprocessing and spelling correction to each review
data['processed_review'] = reviews.apply(preprocess_text)
data['corrected_review'] = data['processed_review'].apply(correct_spelling)

# Print the DataFrame with processed and corrected reviews
print(data[['review', 'corrected_review']])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/tamilselvan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                  review  \
# 0                                         GoodREAD MORE
# 1     Nice camera but battery drain fast specially o...
# 2     Best smart phone under this price range compar...
# 3                                Just amazing!READ MORE
# 4                             Nice UI and FastREAD MORE
# ...                                                 ...
# 1122           Good product thank you FlipkartREAD MORE
# 1123  Great product much faster than iPhone 13READ MORE
# 1124                                   Great 👍READ MORE
# 1125  Very good product and delivered in one day...R...
# 1126                                   AwesomeREAD MORE
#
#                                        corrected_review
# 0                                                  good
# 1     nice camera battery drain fast special video r...
# 2     best smart phone price rang compare phone 2023...
# 3                                                 amaze
# 4                                           nice i fast
# ...                                                 ...
# 1122                        good product thank flippant
# 1123                great product much faster siphon 13
# 1124                                            great i
# 1125                          good product deli one day
# 1126                                            awesome
#
# [1127 rows x 2 columns]
